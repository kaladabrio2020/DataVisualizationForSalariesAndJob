# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Dataset/jobs_in_data.csv')

# %%
dataset.head(3)
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## Trabalhos

# %%
dataset['job_title'].value_counts().reset_index()
# Out:
#                           job_title  count
# 0                     Data Engineer   2195
# 1                    Data Scientist   1989
# 2                      Data Analyst   1388
# 3         Machine Learning Engineer    991
# 4                 Applied Scientist    272
# ..                              ...    ...
# 120        Consultant Data Engineer      1
# 121              Sales Data Analyst      1
# 122  Managing Director Data Science      1
# 123              AWS Data Architect      1
# 124        Deep Learning Researcher      1
#
# [125 rows x 2 columns]

# %%
# irei pergar os trabalhos com mairo quantidade de instancias
select = dataset['job_title'].value_counts().reset_index()
resultado = select.loc[ select['count']>=1000 ]['job_title'].values

# %% [markdown]
# > Só será feito a analise para os dados com maior quantidade de instancias

# %%
datasetNew = dataset.loc[dataset['job_title'].isin(resultado)]

# %%
datasetNew
# Out:
#       work_year       job_title               job_category salary_currency  \
# 3          2023  Data Scientist  Data Science and Research             USD
# 4          2023  Data Scientist  Data Science and Research             USD
# 5          2023  Data Scientist  Data Science and Research             USD
# 6          2023  Data Scientist  Data Science and Research             USD
# 9          2023   Data Engineer           Data Engineering             USD
# ...         ...             ...                        ...             ...
# 9344       2020   Data Engineer           Data Engineering             USD
# 9347       2021  Data Scientist  Data Science and Research             SGD
# 9349       2021   Data Engineer           Data Engineering             EUR
# 9351       2020  Data Scientist  Data Science and Research             USD
# 9353       2020  Data Scientist  Data Science and Research             USD
#
#       salary  salary_in_usd employee_residence experience_level  \
# ...
